# %%
df = pd.read_csv("Online_Retail.csv")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  01/12/10 8:26       2.55     17850.0  United Kingdom
# 1  01/12/10 8:26       3.39     17850.0  United Kingdom
# 2  01/12/10 8:26       2.75     17850.0  United Kingdom
# 3  01/12/10 8:26       3.39     17850.0  United Kingdom
# 4  01/12/10 8:26       3.39     17850.0  United Kingdom

# %%
df[df.InvoiceNo == "536365"]
# Out:
# C:\Users\jitin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0  01/12/10 8:26       2.55     17850.0  United Kingdom
# 1  01/12/10 8:26       3.39     17850.0  United Kingdom
# 2  01/12/10 8:26       2.75     17850.0  United Kingdom
# 3  01/12/10 8:26       3.39     17850.0  United Kingdom
# 4  01/12/10 8:26       3.39     17850.0  United Kingdom
# 5  01/12/10 8:26       7.65     17850.0  United Kingdom
# 6  01/12/10 8:26       4.25     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # Data Preprocessing

# %%
print('Number of Unique Invoice numbers: {cnt}'.format(cnt=df.InvoiceNo.nunique()))
print('Number of Unique Customer IDs: {cnt}'.format(cnt=df.CustomerID.nunique()))
# Out:
# Number of Unique Invoice numbers: 25900
# Number of Unique Customer IDs: 4372

# %%
#quantiy = -2 --> returned item

# %%
df = df[df['Quantity']>=0]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531285 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    531285 non-null  object
#  1   StockCode    531285 non-null  object
#  2   Description  530693 non-null  object
#  3   Quantity     531285 non-null  int64
#  4   InvoiceDate  531285 non-null  object
#  5   UnitPrice    531285 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      531285 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.5+ MB

# %%
df.dropna(axis=0, subset=['InvoiceNo'],inplace=True)
df['InvoiceNo']=df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          486286
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
data = (df[df['Country'] =="United Kingdom"].groupby(['InvoiceNo', 'Description'])['Quantity']
               .sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
data.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
# 536368                      0.0                           0.0
# 536369                      0.0                           0.0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                            0.0                          0.0
# 536366                            0.0                          0.0
# 536367                            0.0                          0.0
# 536368                            0.0                          0.0
# 536369                            0.0                          0.0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                            0.0                               0.0
# 536366                            0.0                               0.0
# 536367                            0.0                               0.0
# 536368                            0.0                               0.0
# 536369                            0.0                               0.0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                           0.0                        0.0  ...
# 536366                           0.0                        0.0  ...
# 536367                           0.0                        0.0  ...
# 536368                           0.0                        0.0  ...
# 536369                           0.0                        0.0  ...
#
# Description  returned  taig adjust  test  to push order througha s stock was   \
# InvoiceNo
# 536365            0.0          0.0   0.0                                  0.0
# 536366            0.0          0.0   0.0                                  0.0
# 536367            0.0          0.0   0.0                                  0.0
# 536368            0.0          0.0   0.0                                  0.0
# 536369            0.0          0.0   0.0                                  0.0
#
# Description  website fixed  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo
# 536365                 0.0                  0.0                  0.0
# 536366                 0.0                  0.0                  0.0
# 536367                 0.0                  0.0                  0.0
# 536368                 0.0                  0.0                  0.0
# 536369                 0.0                  0.0                  0.0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                  0.0                   0.0
# 536366                  0.0                   0.0
# 536367                  0.0                   0.0
# 536368                  0.0                   0.0
# 536369                  0.0                   0.0
#
# Description  wrongly sold (22719) barcode
# InvoiceNo
# 536365                                0.0
# 536366                                0.0
# 536367                                0.0
# 536368                                0.0
# 536369                                0.0
#
# [5 rows x 4058 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

data = data.applymap(encode_units)
data
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# 581585                                    0                               0
# 581586                                    0                               0
# A563185                                   0                               0
# A563186                                   0                               0
# A563187                                   0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# ...                         ...                           ...
# 581585                        0                             0
# 581586                        0                             0
# A563185                       0                             0
# A563186                       0                             0
# A563187                       0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536369                              0                            0
# ...                               ...                          ...
# 581585                              0                            0
# 581586                              0                            0
# A563185                             0                            0
# A563186                             0                            0
# A563187                             0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536369                              0                                 0
# ...                               ...                               ...
# 581585                              0                                 0
# 581586                              0                                 0
# A563185                             0                                 0
# A563186                             0                                 0
# A563187                             0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536369                             0                          0  ...
# ...                              ...                        ...  ...
# 581585                             0                          0  ...
# 581586                             0                          0  ...
# A563185                            0                          0  ...
# A563186                            0                          0  ...
# A563187                            0                          0  ...
#
# Description  returned  taig adjust  test  to push order througha s stock was   \
# InvoiceNo
# 536365              0            0     0                                    0
# 536366              0            0     0                                    0
# 536367              0            0     0                                    0
# 536368              0            0     0                                    0
# 536369              0            0     0                                    0
# ...               ...          ...   ...                                  ...
# 581585              0            0     0                                    0
# 581586              0            0     0                                    0
# A563185             0            0     0                                    0
# A563186             0            0     0                                    0
# A563187             0            0     0                                    0
#
# Description  website fixed  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo
# 536365                   0                    0                    0
# 536366                   0                    0                    0
# 536367                   0                    0                    0
# 536368                   0                    0                    0
# 536369                   0                    0                    0
# ...                    ...                  ...                  ...
# 581585                   0                    0                    0
# 581586                   0                    0                    0
# A563185                  0                    0                    0
# A563186                  0                    0                    0
# A563187                  0                    0                    0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                    0                     0
# 536366                    0                     0
# 536367                    0                     0
# 536368                    0                     0
# 536369                    0                     0
# ...                     ...                   ...
# 581585                    0                     0
# 581586                    0                     0
# A563185                   0                     0
# A563186                   0                     0
# A563187                   0                     0
#
# Description  wrongly sold (22719) barcode
# InvoiceNo
# 536365                                  0
# 536366                                  0
# 536367                                  0
# 536368                                  0
# 536369                                  0
# ...                                   ...
# 581585                                  0
# 581586                                  0
# A563185                                 0
# A563186                                 0
# A563187                                 0
#
# [18194 rows x 4058 columns]

# %%
data = data[(data > 0).sum(axis=1) >= 2]
data
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536372                                    0                               0
# ...                                     ...                             ...
# 581582                                    0                               0
# 581583                                    0                               0
# 581584                                    0                               0
# 581585                                    0                               0
# 581586                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536372                        0                             0
# ...                         ...                           ...
# 581582                        0                             0
# 581583                        0                             0
# 581584                        0                             0
# 581585                        0                             0
# 581586                        0                             0
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536372                              0                            0
# ...                               ...                          ...
# 581582                              0                            0
# 581583                              0                            0
# 581584                              0                            0
# 581585                              0                            0
# 581586                              0                            0
#
# Description   RED SPOT GIFT BAG LARGE   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536372                              0                                 0
# ...                               ...                               ...
# 581582                              0                                 0
# 581583                              0                                 0
# 581584                              0                                 0
# 581585                              0                                 0
# 581586                              0                                 0
#
# Description   SPACEBOY BABY GIFT SET   TOADSTOOL BEDSIDE LIGHT   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536372                             0                          0  ...
# ...                              ...                        ...  ...
# 581582                             0                          0  ...
# 581583                             0                          0  ...
# 581584                             0                          0  ...
# 581585                             0                          0  ...
# 581586                             0                          0  ...
#
# Description  returned  taig adjust  test  to push order througha s stock was   \
# InvoiceNo
# 536365              0            0     0                                    0
# 536366              0            0     0                                    0
# 536367              0            0     0                                    0
# 536368              0            0     0                                    0
# 536372              0            0     0                                    0
# ...               ...          ...   ...                                  ...
# 581582              0            0     0                                    0
# 581583              0            0     0                                    0
# 581584              0            0     0                                    0
# 581585              0            0     0                                    0
# 581586              0            0     0                                    0
#
# Description  website fixed  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo
# 536365                   0                    0                    0
# 536366                   0                    0                    0
# 536367                   0                    0                    0
# 536368                   0                    0                    0
# 536372                   0                    0                    0
# ...                    ...                  ...                  ...
# 581582                   0                    0                    0
# 581583                   0                    0                    0
# 581584                   0                    0                    0
# 581585                   0                    0                    0
# 581586                   0                    0                    0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                    0                     0
# 536366                    0                     0
# 536367                    0                     0
# 536368                    0                     0
# 536372                    0                     0
# ...                     ...                   ...
# 581582                    0                     0
# 581583                    0                     0
# 581584                    0                     0
# 581585                    0                     0
# 581586                    0                     0
#
# Description  wrongly sold (22719) barcode
# InvoiceNo
# 536365                                  0
# 536366                                  0
# 536367                                  0
# 536368                                  0
# 536372                                  0
# ...                                   ...
# 581582                                  0
# 581583                                  0
# 581584                                  0
# 581585                                  0
# 581586                                  0
#
# [16539 rows x 4058 columns]

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_itemsets_plus = apriori(data, min_support=0.03,
                                 use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemsets_plus
# Out:
# C:\Users\jitin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# C:\Users\jitin\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                                           itemsets
# 0    0.129875               (WHITE HANGING HEART T-LIGHT HOLDER)
# 1    0.116331                          (JUMBO BAG RED RETROSPOT)
# 2    0.100671                         (REGENCY CAKESTAND 3 TIER)
# 3    0.095471                                    (PARTY BUNTING)
# 4    0.084165                          (LUNCH BAG RED RETROSPOT)
# ..        ...                                                ...
# 172  0.030473                   (CHRISTMAS CRAFT LITTLE FRIENDS)
# 173  0.030473                          (CREAM HEART CARD HOLDER)
# 174  0.030413     (LUNCH BAG CARS BLUE, LUNCH BAG  BLACK SKULL.)
# 175  0.030292  (LUNCH BAG RED RETROSPOT, LUNCH BAG SPACEBOY D...
# 176  0.030171  (LUNCH BAG SUKI DESIGN , LUNCH BAG  BLACK SKULL.)
#
# [177 rows x 2 columns]

# %%
frequent_itemsets_plus['length'] = frequent_itemsets_plus['itemsets'].apply(lambda x: len(x))

frequent_itemsets_plus
# Out:
# C:\Users\jitin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                                           itemsets  length
# 0    0.129875               (WHITE HANGING HEART T-LIGHT HOLDER)       1
# 1    0.116331                          (JUMBO BAG RED RETROSPOT)       1
# 2    0.100671                         (REGENCY CAKESTAND 3 TIER)       1
# 3    0.095471                                    (PARTY BUNTING)       1
# 4    0.084165                          (LUNCH BAG RED RETROSPOT)       1
# ..        ...                                                ...     ...
# 172  0.030473                   (CHRISTMAS CRAFT LITTLE FRIENDS)       1
# 173  0.030473                          (CREAM HEART CARD HOLDER)       1
# 174  0.030413     (LUNCH BAG CARS BLUE, LUNCH BAG  BLACK SKULL.)       2
# 175  0.030292  (LUNCH BAG RED RETROSPOT, LUNCH BAG SPACEBOY D...       2
# 176  0.030171  (LUNCH BAG SUKI DESIGN , LUNCH BAG  BLACK SKULL.)       2
#
# [177 rows x 3 columns]

# %%
from mlxtend.frequent_patterns import association_rules
# Out:
# C:\Users\jitin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
association_rules=association_rules(frequent_itemsets_plus, metric='lift',
                  min_threshold=1).sort_values('lift', ascending=False).reset_index(drop=True)
association_rules.head(5)
# Out:
# C:\Users\jitin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                            antecedents                           consequents  \
# 0    (GREEN REGENCY TEACUP AND SAUCER)      (PINK REGENCY TEACUP AND SAUCER)
# 1     (PINK REGENCY TEACUP AND SAUCER)     (GREEN REGENCY TEACUP AND SAUCER)
# 2     (PINK REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER )
# 3   (ROSES REGENCY TEACUP AND SAUCER )      (PINK REGENCY TEACUP AND SAUCER)
# 4  (GARDENERS KNEELING PAD KEEP CALM )  (GARDENERS KNEELING PAD CUP OF TEA )
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.056473            0.042264  0.034887    0.617773  14.617093
# 1            0.042264            0.056473  0.034887    0.825465  14.617093
# 2            0.042264            0.057682  0.033013    0.781116  13.541798
# 3            0.057682            0.042264  0.033013    0.572327  13.541798
# 4            0.054235            0.045287  0.032711    0.603122  13.317793
#
#    leverage  conviction
# 0  0.032500    2.505674
# 1  0.032500    5.405948
# 2  0.030575    4.305101
# 3  0.030575    2.239413
# 4  0.030254    2.405555

# %%
association_rules
# Out:
# C:\Users\jitin\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                              antecedents  \
# 0      (GREEN REGENCY TEACUP AND SAUCER)
# 1       (PINK REGENCY TEACUP AND SAUCER)
# 2       (PINK REGENCY TEACUP AND SAUCER)
# 3     (ROSES REGENCY TEACUP AND SAUCER )
# 4    (GARDENERS KNEELING PAD KEEP CALM )
# 5   (GARDENERS KNEELING PAD CUP OF TEA )
# 6      (GREEN REGENCY TEACUP AND SAUCER)
# 7     (ROSES REGENCY TEACUP AND SAUCER )
# 8           (ALARM CLOCK BAKELIKE GREEN)
# 9            (ALARM CLOCK BAKELIKE RED )
# 10     (PAPER CHAIN KIT 50'S CHRISTMAS )
# 11   (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 12         (WOODEN FRAME ANTIQUE WHITE )
# 13   (WOODEN PICTURE FRAME WHITE FINISH)
# 14             (LUNCH BAG  BLACK SKULL.)
# 15             (LUNCH BAG PINK POLKADOT)
# 16             (LUNCH BAG  BLACK SKULL.)
# 17              (LUNCH BAG SUKI DESIGN )
# 18              (JUMBO STORAGE BAG SUKI)
# 19   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 20             (LUNCH BAG RED RETROSPOT)
# 21             (LUNCH BAG PINK POLKADOT)
# 22                 (LUNCH BAG CARS BLUE)
# 23             (LUNCH BAG  BLACK SKULL.)
# 24             (JUMBO BAG PINK POLKADOT)
# 25              (JUMBO STORAGE BAG SUKI)
# 26              (LUNCH BAG SUKI DESIGN )
# 27             (LUNCH BAG RED RETROSPOT)
# 28             (LUNCH BAG  BLACK SKULL.)
# 29             (LUNCH BAG RED RETROSPOT)
# 30             (JUMBO BAG RED RETROSPOT)
# 31             (JUMBO BAG PINK POLKADOT)
# 32          (LUNCH BAG SPACEBOY DESIGN )
# 33             (LUNCH BAG RED RETROSPOT)
# 34                 (LUNCH BAG CARS BLUE)
# 35             (LUNCH BAG RED RETROSPOT)
# 36                (JUMBO BAG STRAWBERRY)
# 37             (JUMBO BAG RED RETROSPOT)
# 38             (JUMBO BAG RED RETROSPOT)
# 39      (JUMBO  BAG BAROQUE BLACK WHITE)
# 40             (JUMBO BAG RED RETROSPOT)
# 41              (JUMBO STORAGE BAG SUKI)
# 42             (JUMBO BAG RED RETROSPOT)
# 43   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 44             (JUMBO BAG RED RETROSPOT)
# 45                    (JUMBO BAG APPLES)
# 46             (JUMBO BAG RED RETROSPOT)
# 47             (LUNCH BAG RED RETROSPOT)
#
#                              consequents  antecedent support  \
# 0       (PINK REGENCY TEACUP AND SAUCER)            0.056473
# 1      (GREEN REGENCY TEACUP AND SAUCER)            0.042264
# 2     (ROSES REGENCY TEACUP AND SAUCER )            0.042264
# 3       (PINK REGENCY TEACUP AND SAUCER)            0.057682
# 4   (GARDENERS KNEELING PAD CUP OF TEA )            0.054235
# 5    (GARDENERS KNEELING PAD KEEP CALM )            0.045287
# 6     (ROSES REGENCY TEACUP AND SAUCER )            0.056473
# 7      (GREEN REGENCY TEACUP AND SAUCER)            0.057682
# 8            (ALARM CLOCK BAKELIKE RED )            0.052663
# 9           (ALARM CLOCK BAKELIKE GREEN)            0.056170
# 10   (PAPER CHAIN KIT VINTAGE CHRISTMAS)            0.067598
# 11     (PAPER CHAIN KIT 50'S CHRISTMAS )            0.048129
# 12   (WOODEN PICTURE FRAME WHITE FINISH)            0.056835
# 13         (WOODEN FRAME ANTIQUE WHITE )            0.064937
# 14             (LUNCH BAG PINK POLKADOT)            0.073402
# 15             (LUNCH BAG  BLACK SKULL.)            0.060765
# 16              (LUNCH BAG SUKI DESIGN )            0.073402
# 17             (LUNCH BAG  BLACK SKULL.)            0.061733
# 18   (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.068323
# 19              (JUMBO STORAGE BAG SUKI)            0.068444
# 20             (LUNCH BAG PINK POLKADOT)            0.084165
# 21             (LUNCH BAG RED RETROSPOT)            0.060765
# 22             (LUNCH BAG  BLACK SKULL.)            0.064333
# 23                 (LUNCH BAG CARS BLUE)            0.073402
# 24              (JUMBO STORAGE BAG SUKI)            0.069956
# 25             (JUMBO BAG PINK POLKADOT)            0.068323
# 26             (LUNCH BAG RED RETROSPOT)            0.061733
# 27              (LUNCH BAG SUKI DESIGN )            0.084165
# 28             (LUNCH BAG RED RETROSPOT)            0.073402
# 29             (LUNCH BAG  BLACK SKULL.)            0.084165
# 30             (JUMBO BAG PINK POLKADOT)            0.116331
# 31             (JUMBO BAG RED RETROSPOT)            0.069956
# 32             (LUNCH BAG RED RETROSPOT)            0.062761
# 33          (LUNCH BAG SPACEBOY DESIGN )            0.084165
# 34             (LUNCH BAG RED RETROSPOT)            0.064333
# 35                 (LUNCH BAG CARS BLUE)            0.084165
# 36             (JUMBO BAG RED RETROSPOT)            0.047887
# 37                (JUMBO BAG STRAWBERRY)            0.116331
# 38      (JUMBO  BAG BAROQUE BLACK WHITE)            0.116331
# 39             (JUMBO BAG RED RETROSPOT)            0.054659
# 40              (JUMBO STORAGE BAG SUKI)            0.116331
# 41             (JUMBO BAG RED RETROSPOT)            0.068323
# 42   (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.116331
# 43             (JUMBO BAG RED RETROSPOT)            0.068444
# 44                    (JUMBO BAG APPLES)            0.116331
# 45             (JUMBO BAG RED RETROSPOT)            0.053510
# 46             (LUNCH BAG RED RETROSPOT)            0.116331
# 47             (JUMBO BAG RED RETROSPOT)            0.084165
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.042264  0.034887    0.617773  14.617093  0.032500    2.505674
# 1             0.056473  0.034887    0.825465  14.617093  0.032500    5.405948
# 2             0.057682  0.033013    0.781116  13.541798  0.030575    4.305101
# 3             0.042264  0.033013    0.572327  13.541798  0.030575    2.239413
# 4             0.045287  0.032711    0.603122  13.317793  0.030254    2.405555
# 5             0.054235  0.032711    0.722296  13.317793  0.030254    3.405662
# 6             0.057682  0.042385    0.750535  13.011639  0.039127    3.777361
# 7             0.056473  0.042385    0.734801  13.011639  0.039127    3.557807
# 8             0.056170  0.034041    0.646383  11.507574  0.031083    2.669077
# 9             0.052663  0.034041    0.606028  11.507574  0.031083    2.404578
# 10            0.048129  0.032529    0.481216   9.998541  0.029276    1.834814
# 11            0.067598  0.032529    0.675879   9.998541  0.029276    2.876714
# 12            0.064937  0.031925    0.561702   8.649899  0.028234    2.133395
# 13            0.056835  0.031925    0.491620   8.649899  0.028234    1.855236
# 14            0.060765  0.031562    0.429984   7.076117  0.027101    1.647732
# 15            0.073402  0.031562    0.519403   7.076117  0.027101    1.928014
# 16            0.061733  0.030171    0.411038   6.658331  0.025640    1.593086
# 17            0.073402  0.030171    0.488737   6.658331  0.025640    1.812368
# 18            0.068444  0.031018    0.453982   6.632874  0.026341    1.706091
# 19            0.068323  0.031018    0.453180   6.632874  0.026341    1.703809
# 20            0.060765  0.033497    0.397989   6.549584  0.028382    1.560160
# 21            0.084165  0.033497    0.551244   6.549584  0.028382    2.040830
# 22            0.073402  0.030413    0.472744   6.440460  0.025691    1.757397
# 23            0.064333  0.030413    0.414333   6.440460  0.025691    1.597609
# 24            0.068323  0.030534    0.436474   6.388352  0.025754    1.653297
# 25            0.069956  0.030534    0.446903   6.388352  0.025754    1.681520
# 26            0.084165  0.031199    0.505387   6.004737  0.026003    1.851619
# 27            0.061733  0.031199    0.370690   6.004737  0.026003    1.490945
# 28            0.084165  0.036701    0.500000   5.940733  0.030523    1.831671
# 29            0.073402  0.036701    0.436063   5.940733  0.030523    1.643088
# 30            0.069956  0.047464    0.408004   5.832308  0.039326    1.571032
# 31            0.116331  0.047464    0.678479   5.832308  0.039326    2.748400
# 32            0.084165  0.030292    0.482659   5.734696  0.025010    1.770274
# 33            0.062761  0.030292    0.359914   5.734696  0.025010    1.464239
# 34            0.084165  0.030776    0.478383   5.683897  0.025361    1.755764
# 35            0.064333  0.030776    0.365661   5.683897  0.025361    1.475027
# 36            0.116331  0.031259    0.652778   5.611378  0.025689    2.544966
# 37            0.047887  0.031259    0.268711   5.611378  0.025689    1.301966
# 38            0.054659  0.034464    0.296258   5.420141  0.028105    1.343306
# 39            0.116331  0.034464    0.630531   5.420141  0.028105    2.391727
# 40            0.068323  0.042203    0.362786   5.309837  0.034255    1.462109
# 41            0.116331  0.042203    0.617699   5.309837  0.034255    2.311449
# 42            0.068444  0.039724    0.341476   4.989110  0.031762    1.414612
# 43            0.116331  0.039724    0.580389   4.989110  0.031762    2.105923
# 44            0.053510  0.030715    0.264033   4.934289  0.024490    1.286050
# 45            0.116331  0.030715    0.574011   4.934289  0.024490    2.074395
# 46            0.084165  0.032106    0.275988   3.279136  0.022315    1.264944
# 47            0.116331  0.032106    0.381466   3.279136  0.022315    1.428649
